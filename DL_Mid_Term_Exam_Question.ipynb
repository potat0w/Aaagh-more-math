# %% [markdown]
# <a href="https://colab.research.google.com/github/potat0w/Aaagh-more-math/blob/main/DL_Mid_Term_Exam_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DL Mid term exam
#
# **Name:*Kahon Binte Zaman*
#
# **Course Email:*kahonbintezaman@gmail.com*
#
# ## End of Assignment
#
# Before submitting:
# - Run all cells from top to bottom.
# - Check that all answer sections are filled.
# - Instruction video অনুযায়ী আমাদের দেয়া Colab ফাইলটি থেকে প্রথম একটি Save copy in drive করে নিবা। এরপর Google colab এর মধ্যে কোডগুলো করবে এবং সেই ফাইলটি ‘Anyone with the link’ & ‘View’ Access দিয়ে ফাইলটির Shareble Link টি সাবমিট করবে।

# %% [markdown]
# # Question 01: [ Marks 10 ]
#
# Draw a Neural Network
#
# Draw a neural network with:
#
# 3 input features
#
# 3 hidden layers (at least 2 neurons each)
#
# 1 output neuron
#
# a) Label all weights and biases. <br>
# b) Write the forward equations layer by layer. <br>
# c) If output uses Sigmoid, write the final prediction equation. <br>
#
# Please note : Don't forget to attach a screen short of your neural network.

# %% [markdown]
# **Write** Answer 01:

# %% [markdown]
# ![WhatsApp Image 2026-02-27 at 8.38.37 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2026-02-27 at 8.38.38 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Question 02: [ Marks 20 ]
#
# Manual Gradient Calculation
#
# Given:
#
# z = w*x + b <br>
# y_pred = sigmoid(z) <br>
# L = −[ y log(y_pred) + (1−y) log(1−y_pred) ] <br>
#
# a) Write dL/dy_pred <br>
# b) Write dy_pred/dz <br>
# c) Show that dL/dz = y_pred − y <br>

# %% [markdown]
# ## Write Answer 02:

# %% [markdown]
# ![WhatsApp Image 2026-02-27 at 8.38.38 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Question 03: [ Marks 15 ]
#
# x = 3
# y1 = x^2
# y2 = 4*x
# L = y1 + y2
#
# a) Draw the computation graph. <br>
# b) Compute dL/dx manually. <br>
# c) Explain how would you do it using Autograd <br>

# %% [markdown]
# ## Write Answer 03:

# %% [markdown]
# ![WhatsApp Image 2026-02-27 at 8.38.39 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2026-02-27 at 8.38.39 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Question 04: [ Marks 15 ]
#
# Create a scalar tensor x = 3.0 with gradient tracking enabled. <br>
# Compute y = x² + 4x. <br>
# Perform backpropagation. <br>
# Print the gradient of x. <br>
#
# Write the full PyTorch code yourself. <br>

# %% [markdown]
# ## Write Answer 04:

# %%
import torch

x = torch.tensor(3.0, requires_grad=True)

y = x**2 + 4*x

y.backward()

print("Gradient of x:", x.grad)
# Out:
# Gradient of x: tensor(10.)

# %% [markdown]
# # Question 05: [ Marks 10 ]
#
# Create two tensors:
# w = 2.0 (requires_grad=True) <br>
# b = 1.0 (requires_grad=True) <br>
#
# Let input x = 3.0. <br>
# Compute z = w*x + b. <br>
# Use Sigmoid to get y_pred.
#  <br>
#
# Define Binary Cross Entropy manually (without built-in loss). <br>
# Compute gradients using backward(). <br>
# Print gradients of w and b. <br>
#
# Write full code.

# %% [markdown]
# ## Write Answer 05:

# %%
import torch

w = torch.tensor(2.0, requires_grad=True)
b = torch.tensor(1.0, requires_grad=True)

x = torch.tensor(3.0)
y = torch.tensor(1.0)

z = w*x + b
y_pred = torch.sigmoid(z)

L = -(y*torch.log(y_pred) + (1-y)*torch.log(1-y_pred))

L.backward()

print("w grad:", w.grad)
print("b grad:", b.grad)
# Out:
# w grad: tensor(-0.0027)
# b grad: tensor(-0.0009)

# %% [markdown]
# # Question 06: [ Marks 10 ]
#
# Create a tensor x = 2.0 (requires_grad=True). <br>
# Compute:
#
# y1 = x² <br>
# y2 = 3x <br>
# L = y1 + y2 <br>
#
# Call backward(). <br>
# Print x.grad. <br>
#
# Write full PyTorch code.

# %% [markdown]
# ## Write Answer 06:

# %%
import torch

x = torch.tensor(2.0, requires_grad=True)
y1 = x**2
y2 = 3 * x
L = y1 + y2
L.backward()
print("Grad of x:", x.grad)
# Out:
# Grad of x: tensor(7.)

# %% [markdown]
# # Question 07: [ Marks 20 ]
#
#
# Create tensor w = 2.0 (requires_grad=True). <br>
#
# Compute two different losses sequentially and call backward() twice. <br>
# Print w.grad. <br>
#
# Do not clear gradients. <br>
# Explain what you observe. <br>
#
# Write full code.

# %% [markdown]
# ## Write Answer 07:

# %%
import torch

w = torch.tensor(2.0, requires_grad=True)
L1 = 2*w
L1.backward()
print("After first backward:")
print(w.grad)
L2 = 3 * w
L2.backward()
print("After second backward without clearing grad:")
print( w.grad)
# Out:
# After first backward:
# tensor(2.)
# After second backward without clearing grad:
# tensor(5.)

# %% [markdown]
# Gradients accumulate by default in PyTorch.
# Calling backward() multiple times adds the new gradient to the existing w.grad instead of replacing it.
# So after two backward calls, w.grad becomes the sum of both gradients.
