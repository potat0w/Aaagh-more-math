# %% [markdown]
# <a href="https://colab.research.google.com/github/potat0w/Aaagh-more-math/blob/main/nn_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # version 1

# %%
import torch
import torch.nn as nn

# %%
# class Model(nn.Module):
#   def __init__(self,num_features):
#     super().__init__()

#     self.linear = nn.Linear(num_features,1)
#     self.sigmoid = nn.Sigmoid()


#   def forward(self,features):
#     out = self.linear(features)
#     out = self.sigmoid(out)

#     return out

# %% [markdown]
# # Version 2

# %%
# class Model(nn.Module):
#   def __init__(self,num_features):
#     super().__init__()

#     #layer 1

#     self.linear1 = nn.Linear(num_features,3)
#     self.relu = nn.ReLU()

#     #layer 2
#     self.linear2 = nn.Linear(3,1)
#     self.sigmoid = nn.Sigmoid()


#   def forward(self,features):
#     out = self.linear1(features)
#     out = self.relu(out)

#     out = self.linear2(out)
#     out = self.sigmoid(out)

#     return out

# %%
# Version 3


class Model(nn.Module):
  def __init__(self,num_features):
    super().__init__()

    self.network = nn.Sequential(
        nn.Linear(num_features,3), #index 0
        nn.ReLU() ,   #index 1
        nn.Linear(3,1),  #index 2
        nn.Sigmoid()  #index 3

    )

  def forward(self,features):
    out = self.network(features)

    return out

# %%
# Create dataset

features = torch.rand(10,5)

# %%
features
# Out:
# tensor([[0.9322, 0.3083, 0.2931, 0.7230, 0.3059],
#         [0.4391, 0.9710, 0.4283, 0.3871, 0.4714],
#         [0.9911, 0.9407, 0.4284, 0.4875, 0.3280],
#         [0.7550, 0.9304, 0.6254, 0.4636, 0.7977],
#         [0.4607, 0.6236, 0.9431, 0.5994, 0.7690],
#         [0.5083, 0.1648, 0.8658, 0.9948, 0.4738],
#         [0.7999, 0.9440, 0.5801, 0.3206, 0.2271],
#         [0.5119, 0.3701, 0.4453, 0.7206, 0.9751],
#         [0.7398, 0.1720, 0.0326, 0.6672, 0.6971],
#         [0.0491, 0.5664, 0.3486, 0.2348, 0.5570]])

# %%
features.shape[1]
# Out:
# 5

# %%
#create model

model = Model(features.shape[1])

# %%
#calling model for forward pass
# model.forward(features)

model(features)
# Out:
# tensor([[0.5257],
#         [0.5141],
#         [0.5413],
#         [0.5413],
#         [0.5074],
#         [0.5066],
#         [0.5141],
#         [0.5074],
#         [0.5086],
#         [0.4862]], grad_fn=<SigmoidBackward0>)

# %%
#show model weights

model.network[3].weight
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-879/976217913.py in <cell line: 0>()
#       1 #show model weights
#       2
# ----> 3 model.network[3].weight
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1963             if name in modules:
#    1964                 return modules[name]
# -> 1965         raise AttributeError(
#    1966             f"'{type(self).__name__}' object has no attribute '{name}'"
#    1967         )
#
# AttributeError: 'Sigmoid' object has no attribute 'weight'

# %%
# visualize

# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
from torchinfo import summary

summary( model,input_size = (10,5) )
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model                                    [10, 1]                   --
# ├─Sequential: 1-1                        [10, 1]                   --
# │    └─Linear: 2-1                       [10, 3]                   18
# │    └─ReLU: 2-2                         [10, 3]                   --
# │    └─Linear: 2-3                       [10, 1]                   4
# │    └─Sigmoid: 2-4                      [10, 1]                   --
# ==========================================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================

# %% [markdown]
# # Extra

# %%
# Base Class
class Rectangle:
    def __init__(self, length, width):
        print("Rectangle constructor called")
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


# Child Class (Square inherits Rectangle)
class Square(Rectangle):
    def __init__(self, side):
        print("Square constructor called")
        super().__init__(side, side)   # Calls Rectangle constructor

    def square_info(self):
        return f"Square area: {self.area()}"


# Child Class (Cube inherits Square)
class Cube(Square):
    def __init__(self, side):
        print("Cube constructor called")
        super().__init__(side)   # Calls Square constructor

    def volume(self):
        return self.length ** 3


# Create Object
cube = Cube(4)

print("Area:", cube.area())
print("Volume:", cube.volume())
